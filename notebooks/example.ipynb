# %%
import pandas as pd
from jsonapi_client import Session, Modifier

atlanteco_endpoint = 'super-studies/atlanteco/flagship-studies'
with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    studies = map(lambda r: r.json, mgnify.iterate(atlanteco_endpoint))
    studies = pd.json_normalize(studies)
studies[:5]
# Out:
#       type            id attributes.accession attributes.bioproject  \
# 0  studies  MGYS00002392         MGYS00002392             PRJEB6610
# 1  studies  MGYS00006613         MGYS00006613            PRJEB40759
# 2  studies  MGYS00006612         MGYS00006612            PRJEB40763
# 3  studies  MGYS00006611         MGYS00006611            PRJEB55999
# 4  studies  MGYS00006610         MGYS00006610            PRJEB56005
#
#    attributes.samples-count  attributes.is-private attributes.last-update  \
# 0                      1073                  False    2024-04-15T20:15:45
# 1                        58                  False    2024-03-01T18:29:37
# 2                        48                  False    2024-03-01T18:14:18
# 3                        63                  False    2024-03-01T18:01:09
# 4                        50                  False    2024-03-01T17:44:36
#
#   attributes.secondary-accession         attributes.centre-name  \
# 0                      ERP006157                            GSC
# 1                      ERP124426  Ocean Sampling Day Consortium
# 2                      ERP124432  Ocean Sampling Day Consortium
# 3                      ERP140920  Ocean Sampling Day Consortium
# 4                      ERP140926  Ocean Sampling Day Consortium
#
#                            attributes.study-abstract  \
# 0  Analysis of 18S DNA in Tara Oceans Protists si...
# 1  Ocean Sampling Day was initiated by the EU-fun...
# 2  Ocean Sampling Day was initiated by the EU-fun...
# 3  Ocean Sampling Day was initiated by the EU-fun...
# 4  Ocean Sampling Day was initiated by the EU-fun...
#
#                                attributes.study-name  \
# 0  Amplicon sequencing of Tara Oceans DNA samples...
# 1  18S rRNA amplicon sequencing from the Ocean Sa...
# 2  18S rRNA amplicon sequencing from the Ocean Sa...
# 3  18S rRNA amplicon sequencing from the Ocean Sa...
# 4  18S rRNA amplicon sequencing from the Ocean Sa...
#
#   attributes.data-origination  \
# 0                   SUBMITTED
# 1                   SUBMITTED
# 2                   SUBMITTED
# 3                   SUBMITTED
# 4                   SUBMITTED
#
#                            relationships.biomes.data
# 0  [{'id': 'root:Environmental:Aquatic:Marine', '...
# 1  [{'id': 'root:Environmental:Aquatic:Marine', '...
# 2  [{'id': 'root:Environmental:Aquatic:Marine', '...
# 3  [{'id': 'root:Environmental:Aquatic:Marine', '...
# 4  [{'id': 'root:Environmental:Aquatic:Marine', '...

# %%
studies_samples = []

with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    for idx, study in studies[:6].iterrows():
        print(f"fetching {study.id} samples")
        samples = map(lambda r: r.json, mgnify.iterate(f'studies/{study.id}/samples?page_size=1000'))
        samples = pd.json_normalize(samples)
        samples = pd.DataFrame(data={
            'accession': samples['id'],
            'sample_id': samples['id'],
            'study': study.id, 
            'lon': samples['attributes.longitude'],
            'lat': samples['attributes.latitude'],
            'color': "#FF0000",
        })
        samples.set_index('accession', inplace=True)
        studies_samples.append(samples)
studies_samples = pd.concat(studies_samples)
# Out:
# fetching MGYS00002392 samples
# fetching MGYS00006613 samples
# fetching MGYS00006612 samples
# fetching MGYS00006611 samples
# fetching MGYS00006610 samples
# fetching MGYS00006609 samples

# %%
print(f"fetched {len(studies_samples)} samples")

studies_samples[studies_samples.lon.isna()]
# Out:
# fetched 1485 samples
#                sample_id         study  lon  lat    color
# accession
# ERS5150844    ERS5150844  MGYS00006613  NaN  NaN  #FF0000
# ERS13444812  ERS13444812  MGYS00006611  NaN  NaN  #FF0000
# ERS13444813  ERS13444813  MGYS00006611  NaN  NaN  #FF0000
# ERS13444961  ERS13444961  MGYS00006610  NaN  NaN  #FF0000
# ERS13444962  ERS13444962  MGYS00006610  NaN  NaN  #FF0000

# %%
import leafmap.foliumap as leafmap

m = leafmap.Map(center=(0, 0), zoom=2)
m.add_points_from_xy(
    studies_samples.dropna(),
    x='lon', 
    y='lat', 
    popup=["study", "sample_id"], 
    color_column='color',
    add_legend=False
)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6daee263f8b44037fcab5effbbd4ce63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6daee263f8b44037fcab5effbbd4ce63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6daee263f8b44037fcab5effbbd4ce63 = L.map(
#                 &quot;map_6daee263f8b44037fcab5effbbd4ce63&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_6daee263f8b44037fcab5effbbd4ce63);
#
#
#
#
#
#             var tile_layer_17d08f74963b1d127ffd53c351e8d608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17d08f74963b1d127ffd53c351e8d608.addTo(map_6daee263f8b44037fcab5effbbd4ce63);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_6daee263f8b44037fcab5effbbd4ce63);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_f8fd38105474a54f61f3f30adbde78ef = new L.featureGroup().addTo(
#                 map_6daee263f8b44037fcab5effbbd4ce63
#             );
#             options.edit.featureGroup = drawnItems_draw_control_f8fd38105474a54f61f3f30adbde78ef;
#             var draw_control_f8fd38105474a54f61f3f30adbde78ef = new L.Control.Draw(
#                 options
#             ).addTo( map_6daee263f8b44037fcab5effbbd4ce63 );
#             map_6daee263f8b44037fcab5effbbd4ce63.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_f8fd38105474a54f61f3f30adbde78ef.addLayer(layer);
#              });
#             map_6daee263f8b44037fcab5effbbd4ce63.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_f8fd38105474a54f61f3f30adbde78ef.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_7a4ac2da5ac77ef3ca7d32a46848a2f6 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_6daee263f8b44037fcab5effbbd4ce63.addControl(measure_control_7a4ac2da5ac77ef3ca7d32a46848a2f6);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })

# %%
analyses = []
with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    for idx, sample in studies_samples[:10].iterrows():
        print(f"processing {sample.sample_id}")
        filtering = Modifier(f"pipeline_version=5.0&sample_accession={sample.sample_id}&experiment_type=assembly")
        analysis = map(lambda r: r.json, mgnify.iterate('analyses', filter=filtering))
        analysis = pd.json_normalize(analysis)
        analyses.append(analysis)
analyses = pd.concat(analyses)
analyses[:5]
# Out:
# processing ERS1308453
# processing ERS1308521
# processing ERS1308921
# processing ERS1309516
# processing ERS1309432
# processing ERS1309458
# processing ERS1309668
# processing ERS506046
# processing ERS489065
# processing ERS490105
#             type            id attributes.analysis-status  \
# 0  analysis-jobs  MGYA00607591                  completed
# 0  analysis-jobs  MGYA00607600                  completed
# 0  analysis-jobs  MGYA00607626                  completed
# 0  analysis-jobs  MGYA00607624                  completed
# 0  analysis-jobs  MGYA00607602                  completed
#
#   attributes.experiment-type  \
# 0                   assembly
# 0                   assembly
# 0                   assembly
# 0                   assembly
# 0                   assembly
#
#                          attributes.analysis-summary attributes.accession  \
# 0  [{'key': 'Submitted nucleotide sequences', 'va...         MGYA00607591
# 0  [{'key': 'Submitted nucleotide sequences', 'va...         MGYA00607600
# 0  [{'key': 'Submitted nucleotide sequences', 'va...         MGYA00607626
# 0  [{'key': 'Submitted nucleotide sequences', 'va...         MGYA00607624
# 0  [{'key': 'Submitted nucleotide sequences', 'va...         MGYA00607602
#
#   attributes.pipeline-version  attributes.is-private  \
# 0                         5.0                  False
# 0                         5.0                  False
# 0                         5.0                  False
# 0                         5.0                  False
# 0                         5.0                  False
#
#        attributes.last-update attributes.complete-time  \
# 0  2024-01-29T15:29:19.757516      2022-08-26T16:36:56
# 0  2024-01-29T15:29:19.757516      2022-08-26T23:33:27
# 0  2024-01-29T15:29:19.757516      2022-08-27T18:25:22
# 0  2024-01-29T15:29:19.757516      2022-08-27T17:24:19
# 0  2024-01-29T15:29:19.757516      2022-08-27T01:59:36
#
#   attributes.instrument-platform attributes.instrument-model  \
# 0                       ILLUMINA         Illumina HiSeq 2500
# 0                       ILLUMINA         Illumina HiSeq 2000
# 0                       ILLUMINA         Illumina HiSeq 2000
# 0                       ILLUMINA         Illumina HiSeq 2000
# 0                       ILLUMINA         Illumina HiSeq 2000
#
#   relationships.assembly.data.id relationships.assembly.data.type  \
# 0                     ERZ7462356                       assemblies
# 0                     ERZ7512791                       assemblies
# 0                     ERZ7462167                       assemblies
# 0                     ERZ7462236                       assemblies
# 0                     ERZ7463532                       assemblies
#
#   relationships.study.data.id relationships.study.data.type  \
# 0                MGYS00006058                       studies
# 0                MGYS00006058                       studies
# 0                MGYS00006058                       studies
# 0                MGYS00006058                       studies
# 0                MGYS00006058                       studies
#
#   relationships.sample.data.id relationships.sample.data.type
# 0                   ERS1308453                        samples
# 0                   ERS1308521                        samples
# 0                   ERS1308921                        samples
# 0                   ERS1309516                        samples
# 0                   ERS1309432                        samples

# %%
identifier = "go-terms"
go_term = 'GO:0015878'
go_data = []
with Session("https://www.ebi.ac.uk/metagenomics/api/v1") as mgnify:
    for idx, mgya in analyses.iterrows():
        print(f"processing {mgya.id}")
        analysis_identifier = map(lambda r: r.json, mgnify.iterate(f'analyses/{mgya.id}/{identifier}'))
        analysis_identifier = pd.json_normalize(analysis_identifier)
        go_data.append("#0000FF" if go_term in list(analysis_identifier.id) else "#FF0000")
analyses.insert(2, identifier, go_data, True)
# Out:
# processing MGYA00607591
# processing MGYA00607600
# processing MGYA00607626
# processing MGYA00607624
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6         print(f"processing {mgya.id}")
#       7         analysis_identifier = map(lambda r: r.json, mgnify.iterate(f'analyses/{mgya.id}/{identifier}'))
# ----> 8         analysis_identifier = pd.json_normalize(analysis_identifier)
#       9         go_data.append("#0000FF" if go_term in list(analysis_identifier.id) else "#FF0000")
#      10 analyses.insert(2, identifier, go_data, True)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/pandas/io/json/_normalize.py:443, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     439     data = [data]
#     440 elif isinstance(data, abc.Iterable) and not isinstance(data, str):
#     441     # GH35923 Fix pd.json_normalize to not skip the first element of a
#     442     # generator input
# --> 443     data = list(data)
#     444 else:
#     445     raise NotImplementedError
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/session.py:369, in Session._iterate_sync(self, resource_type, filter)
#     366 def _iterate_sync(self, resource_type: str, filter: 'Modifier'=None) \
#     367         -> 'Iterator[ResourceObject]':
#     368     doc = self.get(resource_type, filter)
# --> 369     yield from doc._iterator_sync()
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/document.py:124, in Document._iterator_sync(self)
#     121 yield from self.resources
#     123 if self.links.next:
# --> 124     next_doc = self.links.next.fetch()
#     125     yield from next_doc.iterator()
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/objects.py:107, in Link.fetch(self)
#     105     return self.fetch_async()
#     106 else:
# --> 107     return self.fetch_sync()
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/objects.py:101, in Link.fetch_sync(self)
#      99 self.session.assert_sync()
#     100 if self:
# --> 101     return self.session.fetch_document_by_url(self.url)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/session.py:457, in Session.fetch_document_by_url(self, url)
#     450 """
#     451 Internal use.
#     452
#     453 Fetch Document from server by url.
#     454 """
#     456 # TODO: should we try to guess type, id from url?
# --> 457 return self.documents_by_link.get(url) or self._ext_fetch_by_url(url)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/session.py:471, in Session._ext_fetch_by_url(self, url)
#     470 def _ext_fetch_by_url(self, url: str) -> 'Document':
# --> 471     json_data = self._fetch_json(url)
#     472     return self.read(json_data, url)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/jsonapi_client/session.py:488, in Session._fetch_json(self, url)
#     486 parsed_url = urlparse(url)
#     487 logger.info('Fetching document from url %s', parsed_url)
# --> 488 response = requests.get(parsed_url.geturl(), **self._request_kwargs)
#     489 response_content = response.json()
#     490 if response.status_code == HttpStatus.OK_200:
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /datadrive/apps/miniforge3/envs/mgnify_misc/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = analyses.join(studies_samples.set_index('sample_id'), on='relationships.sample.data.id')
df2 = df[[identifier, 'lon', 'lat', 'study', 'attributes.accession', 'relationships.study.data.id', 'relationships.sample.data.id', 'relationships.assembly.data.id']].copy()
df2 = df2.set_index("study")
df2 = df2.rename(columns={"attributes.accession": "analysis_ID", 
                          'relationships.study.data.id': "study_ID",
                          'relationships.sample.data.id': "sample_ID", 
                          'relationships.assembly.data.id': "assembly_ID"
                         })
m = leafmap.Map(center=(0, 0), zoom=2)
m.add_points_from_xy(df2, 
                     x='lon', 
                     y='lat', 
                     popup=["study_ID", "sample_ID", "assembly_ID", "analysis_ID"],
                    color_column=identifier, add_legend=False)
m

# %%
import leafmap.foliumap as leafmap

# %%
m = leafmap.Map()
m.add_basemap("HYBRID")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7aed9ca37b607520845d2a4f29de26d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7aed9ca37b607520845d2a4f29de26d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7aed9ca37b607520845d2a4f29de26d = L.map(
#                 &quot;map_c7aed9ca37b607520845d2a4f29de26d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_c7aed9ca37b607520845d2a4f29de26d);
#
#
#
#
#
#             var tile_layer_088cfb801883a7224b1f7501801e0e21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_088cfb801883a7224b1f7501801e0e21.addTo(map_c7aed9ca37b607520845d2a4f29de26d);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c7aed9ca37b607520845d2a4f29de26d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_5d65099de11ddc1d82be8f456e25c676 = new L.featureGroup().addTo(
#                 map_c7aed9ca37b607520845d2a4f29de26d
#             );
#             options.edit.featureGroup = drawnItems_draw_control_5d65099de11ddc1d82be8f456e25c676;
#             var draw_control_5d65099de11ddc1d82be8f456e25c676 = new L.Control.Draw(
#                 options
#             ).addTo( map_c7aed9ca37b607520845d2a4f29de26d );
#             map_c7aed9ca37b607520845d2a4f29de26d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_5d65099de11ddc1d82be8f456e25c676.addLayer(layer);
#              });
#             map_c7aed9ca37b607520845d2a4f29de26d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_5d65099de11ddc1d82be8f456e25c676.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_e48462eb7aec0c2ef5433263c29743de = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_c7aed9ca37b607520845d2a4f29de26d.addControl(measure_control_e48462eb7aec0c2ef5433263c29743de);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#
#             var geocoderOpts_geocoder_88b84922ada0d314cf8ae374691bdbb6 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderNam
